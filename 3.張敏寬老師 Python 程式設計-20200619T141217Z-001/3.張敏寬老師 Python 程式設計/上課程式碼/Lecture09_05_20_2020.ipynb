# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('chromedriver')
url = 'http://www.ee.nchu.edu.tw'
driver.get(url)

# %%
driver.current_url

# %%
driver.title

# %%
driver.page_source

# %%
url = 'http://www.google.com'
driver.get(url)

# %%
driver.title

# %%
driver.page_source

# %%
driver.back()

# %%
driver.forward()

# %%
driver.refresh()

# %%
driver.fullscreen_window()

# %%
driver.quit()

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('chromedriver')

# %%
url = 'http://google.com/'
driver.get(url)

# %%
driver.page_source

# %%
driver.find_element_by_name('q').send_keys('Min-Kuan Chang')

# %%
from selenium.webdriver.common.keys import Keys

# %%
driver.find_element_by_name('q').send_keys(Keys.ENTER)

# %%
driver.back()

# %%
driver.find_element_by_name('q').send_keys('520')

# %%
driver.find_element_by_name('btnK').click()

# %%
found_item = driver.find_element_by_name('btnK')

# %%
type(found_item)

# %%
found_item

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('chromedriver')

# %%
url = 'http://google.com/'
driver.get(url)

# %%
driver.page_source

# %%
driver.find_element_by_id('gb_70').click()

# %%
driver.page_source

# %%
driver.find_element_by_id('identifierId').send_keys('minkuanc@gmail.com')

# %%
driver.find_element_by_id('identifierNext').click()

# %%
import os

# %%
filename = 'test.txt'
Exist_Bool = os.path.exists(filename)

# %%
type(Exist_Bool)
# Out:
# bool

# %%
Exist_Bool
# Out:
# False

# %%
filename = 'Lecture09_05_20_2020.ipynb'
Exist_Bool = os.path.exists(filename)
Exist_Bool
# Out:
# True

# %%
filename = 'test.txt'
Exist_Bool = os.path.exists(filename)
if Exist_Bool:
    os.remove(filename)
else:
    print(filename + ' 尚未建立')
# Out:
# test.txt 尚未建立

# %%
filename = 'test.txt'
Exist_Bool = os.path.exists(filename)
if Exist_Bool:
    os.remove(filename)
else:
    print(filename + ' 尚未建立')

# %%
os.mkdir('OSExamples')

# %%
Exist_Bool = os.path.exists('OSExamples')

# %%
Exist_Bool
# Out:
# True

# %%
os.remove('OSExamples')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-11-8c4f2a40a47a> in <module>
# ----> 1 os.remove('OSExamples')
#
# PermissionError: [WinError 5] 存取被拒。: 'OSExamples'

# %%
directory = 'TestDir'

if not os.path.exists(directory):
    os.mkdir(directory)
else:
    print('已經存在')

# %%
directory = 'TestDir'

if not os.path.exists(directory):
    os.mkdir(directory)
else:
    print('已經存在')
# Out:
# 已經存在

# %%
directory = 'TestDir'

if os.path.exists(directory):
    os.rmdir(directory)
else:
    print('不存在')

# %%
directory = 'TestDir'

if os.path.exists(directory):
    os.rmdir(directory)
else:
    print('不存在')
# Out:
# 不存在

# %%
os.listdir(path='.')
# Out:
# ['.ipynb_checkpoints',
#  'Anaconda3-2020.02-Windows-x86_64.exe',
#  'chromedriver.exe',
#  'chromedriver_win32.zip',
#  'desktop.ini',
#  'Lecture09_05_20_2020.ipynb',
#  'mosquitto-1.6.9-install-windows-x64.exe',
#  'node-v12.16.3-x64.msi',
#  'NOOBS_v3_3_1.zip',
#  'OSExamples',
#  'pubsubclient-master.zip',
#  'ScreenTaskNoinstall',
#  'ScreenTaskNoinstall_1.0_azo.exe',
#  'SDCardFormatterv5_WinEN',
#  'SDCardFormatterv5_WinEN.zip',
#  'SourceTreeSetup-3.3.8.exe']

# %%
os.listdir(path='./ScreenTaskNoinstall')
# Out:
# ['ScreenTask.exe', 'WebServer', '如何移除.txt', '阿榮福利味 - 免費軟體下載.url']

# %%
os.listdir(path='./pubsubclient-master.zip')
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-18-86dc87251096> in <module>
# ----> 1 os.listdir(path='./pubsubclient-master.zip')
#
# NotADirectoryError: [WinError 267] 目錄名稱無效。: './pubsubclient-master.zip'

# %%
for names in os.listdir(path='.'):
    try:
        string = './'
        dir_name = string + names
        print(os.listdir(path=dir_name))
    except:
        print(dir_name)
        continue
# Out:
# ['Lecture09_05_20_2020-checkpoint.ipynb']
# ./Anaconda3-2020.02-Windows-x86_64.exe
# ./chromedriver.exe
# ./chromedriver_win32.zip
# ./desktop.ini
# ./Lecture09_05_20_2020.ipynb
# ./mosquitto-1.6.9-install-windows-x64.exe
# ./node-v12.16.3-x64.msi
# ./NOOBS_v3_3_1.zip
# []
# ./pubsubclient-master.zip
# ['ScreenTask.exe', 'WebServer', '如何移除.txt', '阿榮福利味 - 免費軟體下載.url']
# ./ScreenTaskNoinstall_1.0_azo.exe
# ['SDCardFormatterv5_WinEN']
# ./SDCardFormatterv5_WinEN.zip
# ./SourceTreeSetup-3.3.8.exe

# %%
os.path.abspath('.')
# Out:
# 'C:\\Users\\user\\Downloads'

# %%
os.path.abspath('..')
# Out:
# 'C:\\Users\\user'

# %%
os.path.abspath('Lecture09_05_20_2020.ipynb')
# Out:
# 'C:\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb'

# %%
os.path.basename('Lecture09_05_20_2020.ipynb')
# Out:
# 'Lecture09_05_20_2020.ipynb'

# %%
os.path.basename('C:\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb')
# Out:
# 'Lecture09_05_20_2020.ipynb'

# %%
os.path.basename('C:\\Users\\user\\Downloads')
# Out:
# 'Downloads'

# %%
os.path.dirname('Lecture09_05_20_2020.ipynb')
# Out:
# ''

# %%
os.path.getsize('Lecture09_05_20_2020.ipynb')
# Out:
# 17099

# %%
os.path.isabs('Lecture09_05_20_2020.ipynb')
# Out:
# False

# %%
os.path.isabs('C:\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb')
# Out:
# True

# %%
os.path.isfile('Lecture09_05_20_2020.ipynb')
# Out:
# True

# %%
os.path.isfile('C:\\Users\\user\\Downloads')
# Out:
# False

# %%
os.path.isdir('C:\\Users\\user\\Downloads')
# Out:
# True

# %%
os.path.isdir('Lecture09_05_20_2020.ipynb')
# Out:
# False

# %%
os.path.split('C:\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb')
# Out:
# ('C:\\Users\\user\\Downloads', 'Lecture09_05_20_2020.ipynb')

# %%
os.path.splitdrive('C:\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb')
# Out:
# ('C:', '\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb')

# %%
directory, filename = os.path.split('C:\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb')

# %%
directory
# Out:
# 'C:\\Users\\user\\Downloads'

# %%
filename
# Out:
# 'Lecture09_05_20_2020.ipynb'

# %%
complete = os.path.split('C:\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb')

# %%
type(complete)
# Out:
# tuple

# %%
complete
# Out:
# ('C:\\Users\\user\\Downloads', 'Lecture09_05_20_2020.ipynb')

# %%
name01 = os.path.join(directory,filename)

# %%
name01
# Out:
# 'C:\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb'

# %%
name02 = os.path.join(complete[0],complete[1])

# %%
name02
# Out:
# 'C:\\Users\\user\\Downloads\\Lecture09_05_20_2020.ipynb'

# %%
os.system('dir')
# Out:
# 0

# %%
os.system('dir')
# Out:
# 0

# %%
os.system('dir')
# Out:
# 0

# %%
os.system('mkdir temp')
# Out:
# 0

# %%
os.system('rmdir temp')
# Out:
# 0

# %%
os.walk('.')
# Out:
# <generator object walk at 0x0000020E629D6CC8>

# %%
for names in os.walk('.'):
    print(names)
# Out:
# ('.', ['.ipynb_checkpoints', 'OSExamples', 'ScreenTaskNoinstall', 'SDCardFormatterv5_WinEN'], ['Anaconda3-2020.02-Windows-x86_64.exe', 'chromedriver.exe', 'chromedriver_win32.zip', 'desktop.ini', 'Lecture09_05_20_2020.ipynb', 'mosquitto-1.6.9-install-windows-x64.exe', 'node-v12.16.3-x64.msi', 'NOOBS_v3_3_1.zip', 'pubsubclient-master.zip', 'ScreenTaskNoinstall_1.0_azo.exe', 'SDCardFormatterv5_WinEN.zip', 'SourceTreeSetup-3.3.8.exe'])
# ('.\\.ipynb_checkpoints', [], ['Lecture09_05_20_2020-checkpoint.ipynb'])
# ('.\\OSExamples', [], [])
# ('.\\ScreenTaskNoinstall', ['WebServer'], ['ScreenTask.exe', '如何移除.txt', '阿榮福利味 - 免費軟體下載.url'])
# ('.\\ScreenTaskNoinstall\\WebServer', [], ['bootstrap.min.css', 'index.html', 'ScreenTask.jpg'])
# ('.\\SDCardFormatterv5_WinEN', ['SDCardFormatterv5_WinEN'], [])
# ('.\\SDCardFormatterv5_WinEN\\SDCardFormatterv5_WinEN', [], ['SD Card Formatter 5.0.1 Setup.exe'])

# %%
for current_dir, sub_dir, current_filenames in os.walk('.'):
    print(sub_dir)
# Out:
# ['.ipynb_checkpoints', 'OSExamples', 'ScreenTaskNoinstall', 'SDCardFormatterv5_WinEN']
# []
# []
# ['WebServer']
# []
# ['SDCardFormatterv5_WinEN']
# []

# %%
for current_dir, sub_dir, current_filenames in os.walk('.'):
    print(current_dir,sub_dir,sep=' ', end = '\n')
# Out:
# . ['.ipynb_checkpoints', 'OSExamples', 'ScreenTaskNoinstall', 'SDCardFormatterv5_WinEN']
# .\.ipynb_checkpoints []
# .\OSExamples []
# .\ScreenTaskNoinstall ['WebServer']
# .\ScreenTaskNoinstall\WebServer []
# .\SDCardFormatterv5_WinEN ['SDCardFormatterv5_WinEN']
# .\SDCardFormatterv5_WinEN\SDCardFormatterv5_WinEN []

# %%
for current_dir, sub_dir, current_filenames in os.walk(os.path.abspath('.')):
    print(current_dir,sub_dir,sep=' ', end = '\n')
# Out:
# C:\Users\user\Downloads ['.ipynb_checkpoints', 'OSExamples', 'ScreenTaskNoinstall', 'SDCardFormatterv5_WinEN']
# C:\Users\user\Downloads\.ipynb_checkpoints []
# C:\Users\user\Downloads\OSExamples []
# C:\Users\user\Downloads\ScreenTaskNoinstall ['WebServer']
# C:\Users\user\Downloads\ScreenTaskNoinstall\WebServer []
# C:\Users\user\Downloads\SDCardFormatterv5_WinEN ['SDCardFormatterv5_WinEN']
# C:\Users\user\Downloads\SDCardFormatterv5_WinEN\SDCardFormatterv5_WinEN []

# %%
for current_dir, sub_dir, current_filenames in os.walk('.'):
    print(current_dir,sub_dir,sep=' ', end = '\n')
# Out:
# . ['.ipynb_checkpoints', 'OSExamples', 'ScreenTaskNoinstall', 'SDCardFormatterv5_WinEN']
# .\.ipynb_checkpoints []
# .\OSExamples []
# .\ScreenTaskNoinstall ['WebServer']
# .\ScreenTaskNoinstall\WebServer []
# .\SDCardFormatterv5_WinEN ['SDCardFormatterv5_WinEN']
# .\SDCardFormatterv5_WinEN\SDCardFormatterv5_WinEN []

# %%
for current_dir, sub_dir, current_filenames in os.walk('.'):
    if current_dir == '.\ScreenTaskNoinstall':
        for filenames in current_filenames:
            print(filenames)
# Out:
# ScreenTask.exe
# 如何移除.txt
# 阿榮福利味 - 免費軟體下載.url

# %%
os.path.split('C:\\Users\\user\\Downloads\\ScreenTaskNoinstall')
# Out:
# ('C:\\Users\\user\\Downloads', 'ScreenTaskNoinstall')

# %%
os.path.basename('C:\\Users\\user\\Downloads\\ScreenTaskNoinstall')
# Out:
# 'ScreenTaskNoinstall'

# %%
for current_dir, sub_dir, current_filenames in os.walk(os.path.abspath('.')):
    if os.path.basename(current_dir) == 'ScreenTaskNoinstall':
        for filenames in current_filenames:
            print(filenames)
# Out:
# ScreenTask.exe
# 如何移除.txt
# 阿榮福利味 - 免費軟體下載.url

# %%
for current_dir, sub_dir, current_filenames in os.walk(os.path.abspath('.')):
    if os.path.split(current_dir)[1] == 'ScreenTaskNoinstall':
        for filenames in current_filenames:
            print(filenames)
# Out:
# ScreenTask.exe
# 如何移除.txt
# 阿榮福利味 - 免費軟體下載.url

# %%
for current_dir, sub_dir, current_filenames in os.walk(os.path.abspath('.')):
    if os.path.basename(current_dir) == 'ScreenTaskNoinstall':
        for filenames in current_filenames:
            print(os.path.join(current_dir,filenames))
# Out:
# C:\Users\user\Downloads\ScreenTaskNoinstall\ScreenTask.exe
# C:\Users\user\Downloads\ScreenTaskNoinstall\如何移除.txt
# C:\Users\user\Downloads\ScreenTaskNoinstall\阿榮福利味 - 免費軟體下載.url

# %%
import os, shutil

# %%
print('Before copying', os.listdir('.'))
# Out:
# Before copying ['.ipynb_checkpoints', 'Anaconda3-2020.02-Windows-x86_64.exe', 'chromedriver.exe', 'chromedriver_win32.zip', 'desktop.ini', 'Lecture09_05_20_2020.ipynb', 'mosquitto-1.6.9-install-windows-x64.exe', 'node-v12.16.3-x64.msi', 'NOOBS_v3_3_1.zip', 'OSExamples', 'pubsubclient-master.zip', 'ScreenTaskNoinstall', 'ScreenTaskNoinstall_1.0_azo.exe', 'SDCardFormatterv5_WinEN', 'SDCardFormatterv5_WinEN.zip', 'SourceTreeSetup-3.3.8.exe']

# %%
shutil.copyfile('Lecture09_05_20_2020.ipynb','Lecture09_05_20_2020.ipynb')
# Out:
# ---------------------------------------------------------------------------
# SameFileError                             Traceback (most recent call last)
# <ipython-input-88-a9bb49e319fb> in <module>
# ----> 1 shutil.copyfile('Lecture09_05_20_2020.ipynb','Lecture09_05_20_2020.ipynb')
#
# ~\anaconda3\lib\shutil.py in copyfile(src, dst, follow_symlinks)
#     102     """
#     103     if _samefile(src, dst):
# --> 104         raise SameFileError("{!r} and {!r} are the same file".format(src, dst))
#     105
#     106     for fn in [src, dst]:
#
# SameFileError: 'Lecture09_05_20_2020.ipynb' and 'Lecture09_05_20_2020.ipynb' are the same file

# %%
shutil.copyfile('Lecture09_05_20_2020.ipynb','Lecture09_05_20_2020_copy.ipynb')
# Out:
# 'Lecture09_05_20_2020_copy.ipynb'

# %%
print('After copying', os.listdir('.'))
# Out:
# After copying ['.ipynb_checkpoints', 'Anaconda3-2020.02-Windows-x86_64.exe', 'chromedriver.exe', 'chromedriver_win32.zip', 'desktop.ini', 'Lecture09_05_20_2020.ipynb', 'Lecture09_05_20_2020_copy.ipynb', 'mosquitto-1.6.9-install-windows-x64.exe', 'node-v12.16.3-x64.msi', 'NOOBS_v3_3_1.zip', 'OSExamples', 'pubsubclient-master.zip', 'ScreenTaskNoinstall', 'ScreenTaskNoinstall_1.0_azo.exe', 'SDCardFormatterv5_WinEN', 'SDCardFormatterv5_WinEN.zip', 'SourceTreeSetup-3.3.8.exe']

# %%
shutil.copyfile('Lecture09_05_20_2020.ipynb','./temp/Lecture09_05_20_2020.ipynb')
# Out:
# './temp/Lecture09_05_20_2020.ipynb'

# %%
print('After copying', os.listdir('./temp'))
# Out:
# After copying ['Lecture09_05_20_2020.ipynb']

# %%
shutil.copytree('./temp','./temp2')
# Out:
# './temp2'

# %%
print('After copying', os.listdir('./temp2'))
# Out:
# After copying ['Lecture09_05_20_2020.ipynb', 'OSExamples']

# %%
shutil.rmtree('./temp2')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-96-28aa12f20053> in <module>
# ----> 1 shutil.rmtree('./temp2')
#
# ~\anaconda3\lib\shutil.py in rmtree(path, ignore_errors, onerror)
#     514             # can't continue even if onerror hook returns
#     515             return
# --> 516         return _rmtree_unsafe(path, onerror)
#     517
#     518 # Allow introspection of whether or not the hardening against symlink
#
# ~\anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     402         os.rmdir(path)
#     403     except OSError:
# --> 404         onerror(os.rmdir, path, sys.exc_info())
#     405
#     406 # Version using fd-based APIs to protect against races
#
# ~\anaconda3\lib\shutil.py in _rmtree_unsafe(path, onerror)
#     400                 onerror(os.unlink, fullname, sys.exc_info())
#     401     try:
# --> 402         os.rmdir(path)
# ...

# %%
shutil.rmtree('./OSExamples')

# %%
shutil.move('./temp','./temp2')
# Out:
# './temp2\\temp'

# %%
shutil.move('./temp','.')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     565     try:
# --> 566         os.rename(src, real_dst)
#     567     except OSError:
#
# FileNotFoundError: [WinError 2] 系統找不到指定的檔案。: './temp' -> '.\\temp'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-99-0d12874ef674> in <module>
# ----> 1 shutil.move('./temp','.')
#
# ~\anaconda3\lib\shutil.py in move(src, dst, copy_function)
#     578             rmtree(src)
#     579         else:
# --> 580             copy_function(src, real_dst)
#     581             os.unlink(src)
#     582     return real_dst
#
# ~\anaconda3\lib\shutil.py in copy2(src, dst, follow_symlinks)
#     264     if os.path.isdir(dst):
# ...
