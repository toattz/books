# %%
print('Hello world!!')
# Out:
# Hello world!!

# %%
print("Hello world!!")
# Out:
# Hello world!!

# %%
Print('Hello world!!')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c20f2b7e85b1> in <module>
# ----> 1 Print('Hello world!!')
#
# NameError: name 'Print' is not defined

# %%
print(2*3)
# Out:
# 6

# %%
print(2**3)
# Out:
# 8

# %%
print(123)
# Out:
# 123

# %%
print(1,2,3)
# Out:
# 1 2 3

# %%
1
# Out:
# 1

# %%
1.2
# Out:
# 1.2

# %%
'12'
# Out:
# '12'

# %%
12
# Out:
# 12

# %%
12+14
# Out:
# 26

# %%
12/3
# Out:
# 4.0

# %%
12*5
# Out:
# 60

# %%
'12'-'23'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-202687d1b02b> in <module>
# ----> 1 '12'-'23'
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
'12'+'23'
# Out:
# '1223'

# %%
1.2e3
# Out:
# 1200.0

# %%
1.2e-3
# Out:
# 0.0012

# %%
1>2
# Out:
# False

# %%
2>1
# Out:
# True

# %%
(1+1)==2
# Out:
# True

# %%
2>=2
# Out:
# True

# %%
1<=2
# Out:
# True

# %%
'str'
# Out:
# 'str'

# %%
"str"
# Out:
# 'str'

# %%
'str"
# Out:
#   File "<ipython-input-27-145f7467ac12>", line 1
#     'str"
#          ^
# SyntaxError: EOL while scanning string literal

# %%
''Hello' world!!!'
# Out:
#   File "<ipython-input-28-b0faaa5e72bb>", line 1
#     ''Hello' world!!!'
#           ^
# SyntaxError: invalid syntax

# %%
''''Hello' world!!!'
# Out:
#   File "<ipython-input-29-9af0c6db0a2d>", line 1
#     ''''Hello' world!!!'
#                         ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
''''Hello' world!!!'''
# Out:
# "'Hello' world!!!"

# %%
1+1.2
# Out:
# 2.2

# %%
True + 1
# Out:
# 2

# %%
False + 1
# Out:
# 1

# %%
12 + '34'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-3ade9454f1fa> in <module>
# ----> 1 12 + '34'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
12 + int('34')
# Out:
# 46

# %%
12.2+float('12.3')
# Out:
# 24.5

# %%
str(12)+'34'
# Out:
# '1234'

# %%
str(12.3)+'34'
# Out:
# '12.334'

# %%
int('hi')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-af01c7eabe7b> in <module>
# ----> 1 int('hi')
#
# ValueError: invalid literal for int() with base 10: 'hi'

# %%
float('12.3.3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-6fe995ad16d0> in <module>
# ----> 1 float('12.3.3')
#
# ValueError: could not convert string to float: '12.3.3'

# %%
10 + 20
# Out:
# 30

# %%
10 + 40
# Out:
# 50

# %%
10 + 12
# Out:
# 22

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a + 12
# Out:
# 22

# %%
a + 13
# Out:
# 23

# %%
a
# Out:
# 10

# %%
type(a)
# Out:
# int

# %%
a = 1.1

# %%
type(a)
# Out:
# float

# %%
a = '12'

# %%
type(a)
# Out:
# str

# %%
a = 12

# %%
b = 1.2

# %%
a + b
# Out:
# 13.2

# %%
a = None

# %%
type(a)
# Out:
# NoneType

# %%
a = 12

# %%
type(a)
# Out:
# int

# %%
a = None

# %%
type(a)
# Out:
# NoneType

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a = 12
b = 3

# %%
a * b
# Out:
# 36

# %%
a / b
# Out:
# 4.0

# %%
a - b
# Out:
# 9

# %%
a + b
# Out:
# 15

# %%
a = 13
b = 5

# %%
a // b
# Out:
# 2

# %%
a % 5
# Out:
# 3

# %%
a = 4
b = 2

# %%
a ** b
# Out:
# 16

# %%
a = '12'
b = '34'

# %%
a + b
# Out:
# '1234'

# %%
a*2+b*3
# Out:
# '1212343434'

# %%
a*2
# Out:
# '1212'

# %%
b*3
# Out:
# '343434'

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a = 12
b = 12

# %%
a >= b
# Out:
# True

# %%
a <= b
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True and True
# Out:
# True

# %%
a = 1
b = 2

# %%
(a>0) and (b<3)
# Out:
# True

# %%
a = -1
b = 2

# %%
(a>0) and (b<3)
# Out:
# False

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
(a>0) or (b<3)
# Out:
# True

# %%
not False
# Out:
# True

# %%
not True
# Out:
# False

# %% [markdown]
# 複合指定算符

# %%
a = 2

# %%
a += 2

# %%
a
# Out:
# 4

# %%
a = 2

# %%
a = a + 2

# %%
a
# Out:
# 4

# %%
a -= 2

# %%
a
# Out:
# 2

# %%
a = 2
b = 3

# %%
min(a,b)
# Out:
# 2

# %%
max(a,b)
# Out:
# 3

# %%
max(1,2,5,3)
# Out:
# 5

# %%
abs(-1)
# Out:
# 1

# %%
abs(-3)
# Out:
# 3

# %%
pow(2,3)
# Out:
# 8

# %%
pow(4,4)
# Out:
# 256

# %%
pow(3,4)
# Out:
# 81

# %%
pow(2,3,5)
# Out:
# 3

# %%
pow(4,2,5)
# Out:
# 1

# %%
(4**2 - pow(4,2,5))/5
# Out:
# 3.0

# %%
4**2 // 5
# Out:
# 3

# %%
round(1.34)
# Out:
# 1

# %%
round(1.56)
# Out:
# 2

# %%
round(1.45,1)
# Out:
# 1.4

# %%
round(1.46,1)
# Out:
# 1.5

# %%
round(1.456,2)
# Out:
# 1.46

# %%
[1,2,3,4,5,6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
a = [1,2,3,4,5,6]

# %%
type(a)
# Out:
# list

# %%
a = [123, 'ggg', 1.324, True]

# %%
a
# Out:
# [123, 'ggg', 1.324, True]

# %%
a = list('Hello world!!!')

# %%
a
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a = list(123456)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-4187ec956851> in <module>
# ----> 1 a = list(123456)
#
# TypeError: 'int' object is not iterable

# %%
a
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a[0]
# Out:
# 'H'

# %%
a[2]
# Out:
# 'l'

# %%
a[4]
# Out:
# 'o'

# %%
a[6]
# Out:
# 'w'

# %%
a
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a[-1]
# Out:
# '!'

# %%
a[-4]
# Out:
# 'd'

# %%
a[-6]
# Out:
# 'r'

# %%
a
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a[1:4]
# Out:
# ['e', 'l', 'l']

# %%
a[:-1]
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!']

# %%
a[::-1]
# Out:
# ['!', '!', '!', 'd', 'l', 'r', 'o', 'w', ' ', 'o', 'l', 'l', 'e', 'H']

# %%
a[4:2:-1]
# Out:
# ['o', 'l']

# %%
a
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a[4:2:-2]
# Out:
# ['o']

# %%
a[4:1:-2]
# Out:
# ['o', 'l']

# %%
a
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a[3] = 'd'

# %%
a
# Out:
# ['H', 'e', 'l', 'd', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a[0:4:2] = 'cc'

# %%
a
# Out:
# ['c', 'e', 'c', 'd', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a = list('Hello world!!!')

# %%
a
# Out:
# ['H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a[0:4:2] = 'ad'

# %%
a
# Out:
# ['a', 'e', 'd', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!']

# %%
a = [[1,2],[3,4]]

# %%
a
# Out:
# [[1, 2], [3, 4]]

# %%
a[0]
# Out:
# [1, 2]

# %%
a[1]
# Out:
# [3, 4]

# %%
a[0][0]
# Out:
# 1

# %%
a[1][0]
# Out:
# 3

# %%
a[1][1]
# Out:
# 4

# %%
a=[[[1,2],[3,4]],[[5,6],[7,8]]]

# %%
a
# Out:
# [[[1, 2], [3, 4]], [[5, 6], [7, 8]]]

# %%
a[0][0][0]
# Out:
# 1

# %%
a[0][1][0]
# Out:
# 3

# %%
a[1][0][0]
# Out:
# 5

# %%
a[1][1][0]
# Out:
# 7

# %%
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-181-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
a =(1,2)

# %%
type(a)
# Out:
# tuple

# %%
a[0]
# Out:
# 1

# %%
a[1]
# Out:
# 2

# %%
b = [1,2,3]

# %%
a = tuple(b)

# %%
a
# Out:
# (1, 2, 3)

# %%
b
# Out:
# [1, 2, 3]

# %%
a = 1, 2, 3

# %%
type(a)
# Out:
# tuple

# %%
a
# Out:
# (1, 2, 3)

# %%
a = tuple(list('Hello world!!!'))

# %%
a
# Out:
# ('H', 'e', 'l', 'l', 'o', ' ', 'w', 'o', 'r', 'l', 'd', '!', '!', '!')

# %%
a[1:5]
# Out:
# ('e', 'l', 'l', 'o')

# %%
a[::-1]
# Out:
# ('!', '!', '!', 'd', 'l', 'r', 'o', 'w', ' ', 'o', 'l', 'l', 'e', 'H')

# %%
a[4:2:-1]
# Out:
# ('o', 'l')

# %%
a[0] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-198-35375c73db1c> in <module>
# ----> 1 a[0] = 'd'
#
# TypeError: 'tuple' object does not support item assignment

# %%
a ={1,2,3}

# %%
a
# Out:
# {1, 2, 3}

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-201-6a1284577a36> in <module>
# ----> 1 a[0]
#
# TypeError: 'set' object does not support indexing

# %%
Letter = 'abc'
Letter_set = set(Letter)
print(Letter_set)
# Out:
# {'b', 'c', 'a'}

# %%
Letter = 'abcc'
Letter_set = set(Letter)
print(Letter_set)
# Out:
# {'b', 'c', 'a'}

# %%
'a' in Letter_set
# Out:
# True

# %%
'd' in Letter_set
# Out:
# False

# %%
{'a', 'b', 'c'} == Letter_set
# Out:
# True

# %%
{'b', 'c'} < Letter_set
# Out:
# True

# %%
'd' not in Letter_set
# Out:
# True

# %%
'a' not in Letter_set
# Out:
# False

# %%
{'a', 'b', 'c', 'd'} > Letter_set
# Out:
# True

# %%
{'a','d'}> Letter_set
# Out:
# False

# %%
a = {'A':10, 'B':9}

# %%
a
# Out:
# {'A': 10, 'B': 9}

# %%
a = {'ba','cd'}

# %%
a
# Out:
# {'ba', 'cd'}

# %%
b = dict(a)

# %%
b
# Out:
# {'c': 'd', 'b': 'a'}

# %%
b = dict([[1,2],[3,4]])

# %%
b
# Out:
# {1: 2, 3: 4}

# %%
b = dict([['A',2],['B',4]])

# %%
b
# Out:
# {'A': 2, 'B': 4}

# %%
b['A']
# Out:
# 2

# %%
b['B']
# Out:
# 4

# %%
b = dict([[1,2],[3,4]])

# %%
b[1]
# Out:
# 2

# %%
b = dict([['A',2],['B',4]])

# %%
'A' in b
# Out:
# True

# %%
'C' in b
# Out:
# False

# %%
'B' in b
# Out:
# True

# %%
b = [1, 2, 3]

# %%
len(b)
# Out:
# 3

# %%
b = 'string'

# %%
len(b)
# Out:
# 6

# %%
b = dict([['A',2],['B',4]])

# %%
len(b)
# Out:
# 2

# %%
b = [1, 2, 3]

# %%
max(b)
# Out:
# 3

# %%
min(b)
# Out:
# 1

# %%
sum(b)
# Out:
# 6

# %%
len(b)
# Out:
# 3

# %%
sum(b)/len(b)
# Out:
# 2.0

# %%
b = [2, 1, 5]

# %%
sorted(b)
# Out:
# [1, 2, 5]

# %%
sorted(b,reverse=False)
# Out:
# [1, 2, 5]

# %%
sorted(b,reverse=True)
# Out:
# [5, 2, 1]

# %%
b = [4, 5, 1, 2, 3]

# %%
Sorted_b = sorted(b)

# %%
Sorted_b
# Out:
# [1, 2, 3, 4, 5]

# %%
b
# Out:
# [4, 5, 1, 2, 3]

# %%
b.sort()
print(b)
# Out:
# [1, 2, 3, 4, 5]

# %%
b = [4, 5, 1, 2, 3]

# %%
b.insert(2,10)

# %%
b
# Out:
# [4, 5, 10, 1, 2, 3]

# %%
b.insert(4,10)

# %%
b
# Out:
# [4, 5, 10, 1, 10, 2, 3]

# %%
b.append(20)

# %%
b
# Out:
# [4, 5, 10, 1, 10, 2, 3, 20]

# %%
b.append(40)

# %%
a = [11, 12, 13]

# %%
b.extend(a)

# %%
b
# Out:
# [4, 5, 10, 1, 10, 2, 3, 20, 40, 11, 12, 13]

# %%
b.index(10)
# Out:
# 2

# %%
b.count(10)
# Out:
# 2

# %%
b.remove(10)

# %%
b
# Out:
# [4, 5, 1, 10, 2, 3, 20, 40, 11, 12, 13]

# %%
b.clear()

# %%
b
# Out:
# []

# %%
b = [1, 3, 5, 2, 4, 1]

# %%
b_2 = b

# %%
b_2
# Out:
# [1, 3, 5, 2, 4, 1]

# %%
b_2[2] = 10

# %%
b_2
# Out:
# [1, 3, 10, 2, 4, 1]

# %%
b
# Out:
# [1, 3, 10, 2, 4, 1]

# %%
b = [1, 3, 5, 2, 4, 1]

# %%
b_2 = b.copy()

# %%
b_2
# Out:
# [1, 3, 5, 2, 4, 1]

# %%
b_2[2] = 10

# %%
b_2
# Out:
# [1, 3, 10, 2, 4, 1]

# %%
b
# Out:
# [1, 3, 5, 2, 4, 1]

# %%
b = (1, 3, 5, 2, 4, 1)

# %%
b
# Out:
# (1, 3, 5, 2, 4, 1)

# %%
b.count(1)
# Out:
# 2

# %%
b.index(1)
# Out:
# 0

# %%
b = 'abc'

# %%
b.upper()
# Out:
# 'ABC'

# %%
b
# Out:
# 'abc'

# %%
b = 'ABC'

# %%
b.lower()
# Out:
# 'abc'

# %%
b = 'abcbdb'

# %%
b
# Out:
# 'abcbdb'

# %%
b.split('b')
# Out:
# ['a', 'c', 'd', '']

# %%
b = 'abcbd'

# %%
b.split('b')
# Out:
# ['a', 'c', 'd']

# %%
b.split('c')
# Out:
# ['ab', 'bd']

# %%
b
# Out:
# 'abcbd'

# %%
a = 'sssd'

# %%
b.join(a)
# Out:
# 'sabcbdsabcbdsabcbdd'

# %%
b = {'a', 'b', 'c'}

# %%
b.add('d')

# %%
b
# Out:
# {'a', 'b', 'c', 'd'}

# %%
a = b.copy()

# %%
a
# Out:
# {'a', 'b', 'c', 'd'}

# %%
b.remove('d')

# %%
b
# Out:
# {'a', 'b', 'c'}

# %%
b.pop()
# Out:
# 'b'

# %%
b
# Out:
# {'a', 'c'}

# %%
b.pop()
# Out:
# 'c'

# %%
b
# Out:
# {'a'}

# %%
b = {'a', 'b', 'c'}

# %%
b.issubset({'a','b'})
# Out:
# False

# %%
b.issuperset({'a','b'})
# Out:
# True

# %%
b = {'a':2, 'b':3}

# %%
b
# Out:
# {'a': 2, 'b': 3}

# %%
a = b.copy()

# %%
a
# Out:
# {'a': 2, 'b': 3}

# %%
b2 = {'a':3, 'c':9}

# %%
b.update(b2)

# %%
b
# Out:
# {'a': 3, 'b': 3, 'c': 9}

# %%
b.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
b.values()
# Out:
# dict_values([3, 3, 9])

# %%
b.items()
# Out:
# dict_items([('a', 3), ('b', 3), ('c', 9)])
